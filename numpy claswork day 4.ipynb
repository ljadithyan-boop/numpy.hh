# %%
import numpy as np
arr=np.array([35,55,75,40,90])
result=np.where(arr>=40,"pass","fail")
print("the result will be:",result)
condition=[arr<40,arr<60,arr<80]
choices=["fail","c","b"]
result=np.select(condition,choices,default="a")
print("the result using select is:",result)
print(np.all(arr>=40))
print(np.any(arr
# Out:
# the result will be: ['fail' 'pass' 'pass' 'pass' 'pass']
# the result using select is: ['fail' 'c' 'b' 'c' 'a']
# False

# %%
import numpy as np
arr=np.array([50, 60, 50, 70, 60, 80])
print(np.unique(arr))
# Out:
# [50 60 70 80]
